# %%
pip install requests pandas fake_useragent bs4 langid pycountry nltk psycopg2-binary
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: requests in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (2.32.4)
# Requirement already satisfied: pandas in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (2.3.0)
# Requirement already satisfied: fake_useragent in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (2.2.0)
# Requirement already satisfied: bs4 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (0.0.2)
# Requirement already satisfied: langid in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (1.1.6)
# Requirement already satisfied: pycountry in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (24.6.1)
# Requirement already satisfied: nltk in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (3.9.1)
# Requirement already satisfied: psycopg2-binary in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (2.9.10)
# Requirement already satisfied: certifi>=2017.4.17 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from requests) (2025.4.26)
# Requirement already satisfied: idna<4,>=2.5 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from requests) (3.10)
# Requirement already satisfied: charset_normalizer<4,>=2 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from requests) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from requests) (2.4.0)
# Requirement already satisfied: numpy>=1.22.4 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from pandas) (2.2.6)
# Requirement already satisfied: pytz>=2020.1 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: beautifulsoup4 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from bs4) (4.13.4)
# Requirement already satisfied: joblib in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from nltk) (1.5.1)
# Requirement already satisfied: click in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from nltk) (8.2.1)
# Requirement already satisfied: regex>=2021.8.3 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from nltk) (4.67.1)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from beautifulsoup4->bs4) (4.14.0)
# Requirement already satisfied: soupsieve>1.2 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from beautifulsoup4->bs4) (2.7)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup
from fake_useragent import UserAgent
import pandas as pd
import os

url = 'https://dev.to/latest'

ua = UserAgent()
userAgent = ua.random
headers = {'User-Agent': userAgent}
page = requests.get(url, headers = headers)
soup = BeautifulSoup(page.content, 'html.parser')

# %%
blog_box = soup.find_all('div', class_='crayons-story')

links = []
titles = []
time_uploaded = []
authors = []
tags = []
reading_times = []

for box in blog_box:
    #links
    if box.find('h2', class_ = 'crayons-story__title') is not None:
        link = box.find('h2', class_ = 'crayons-story__title').a
        link = link['href']
        links.append(link)
    else:
        links.append('None')

    #titles
    if box.find('h2', class_ = 'crayons-story__title') is not None:
        title = box.find('h2', class_ = 'crayons-story__title')
        titles.append(title.text.replace('\n','').strip())
    else:
        titles.append('None')

    #time_uploaded
    if box.find('time', attrs={'datetime': True}) is not None:
        time_upload = box.find('time', attrs={'datetime': True})
        time_upload = time_upload['datetime']
        time_uploaded.append(time_upload)
    else:
        time_uploaded.append('None')

    #authors
    if box.find('a', class_ = 'crayons-story__secondary fw-medium m:hidden') is not None:
        author = box.find('a', class_ = 'crayons-story__secondary fw-medium m:hidden')
        authors.append(author.text.replace('\n','').strip())
    else:
        authors.append('None')

    #tags
    if box.find('div', class_ = "crayons-story__tags") is not None:
        tag = box.find('div', class_ = "crayons-story__tags")
        tags.append(tag.text.replace('\n',' ').strip())
    else:
        tags.append('None')

    #reading_times
    if box.find('div', class_ = "crayons-story__save") is not None:
        reading_time = box.find('div', class_ = "crayons-story__save")
        reading_times.append(reading_time.text.replace('\n',' ').strip())
    else:
        reading_times.append('None')


df = pd.DataFrame({
    'Link': links,
    'Title': titles,
    'Time_Uploaded': time_uploaded,
    'Authors': authors,
    'Tags': tags,
    'Reading_Time': reading_times
})

df = df[df['Link'] != 'None']

df
# Out:
#                                                  Link  \
# 2   https://dev.to/pambrus/top-5-product-analytics...
# 3   https://dev.to/fscss/css-content-replace-and-r...
# 4   https://dev.to/victornu/project-js-cmp-a-javas...
# 5   https://dev.to/zenoguy/so-i-decided-to-learn-v...
# 6   https://dev.to/praveena_2109/benefits-of-open-...
# 25    How AI Agent Companies Go From $0 to Profitable  2025-06-18T09:30:37Z
# 26  jq: The Hidden Dangers in Your Favorite JSON T...  2025-06-18T09:28:57Z
#
#                    Authors                                               Tags  \
# 2            Ambrus Pethes  #snowplow #productanalytics #marketinganalytic...
# 3           FSCSS tutorial                                           #codepen
# 4             Victor BRAUN                      #cpp #javascript #programming
# 5            Shreyan Ghosh                  #vim #neovim #devtools #beginners
# 6           Praveena durai         #opensource #webdev #javascript #beginners
# 7                 sempre76              #webdev #microsoftgraph #sql #graphql
# 8                  Phanhie             #webdev #documentation #html #markdown
# 9             kashan iqbal
# 10                    魔眼天王                                           #harmony
# 11             Molly Scott         #brand #digitalmarketing #consistencybeats
# 12              Jitu Nayak                #flutter #dart #mobile #development
# 13            Lux Seminare           #webdev #design #waitlist #buildinpublic
# 14                Zack Rac               #webdev #programming #javascript #ai
# 15            Pushpit jain               #beginners #webdev #learning #newbie
# 16      Charlie Brinicombe                      #podcast #b2c #growth #mobile
# 17  Ashikur Rahman (NaziL)            #programming #javascript #ai #beginners
# 18                      cz                                               #a2a
# 19                 Bhuvi D                 #showdev #webdev #react #beginners
# 20             Vivien Mahé  #boilerplate #mobile #kotlin #kotlinmultiplatform
# 21     Vijay Dilip Bhosale                  #aws #awsbigdata #awsdatalake #s3
# 22               Sivakumar                                        #linux #cli
# 23                    Anil  #webdev #javascript #frontend #softwaredevelop...
# 24        Apache SeaTunnel              #seatunnel #programming #java #devops
# 25           Arnon Shimoni                                       #ai #startup
# 26                 Camillo                    #programming #cybersecurity #jq
#
#    Reading_Time
# 2    8 min read
# 3    1 min read
# 4    1 min read
# 5    2 min read
# 6    1 min read
# 7    1 min read
# 8    4 min read
# 9    3 min read
# 10   2 min read
# 11   5 min read
# 12   1 min read
# 13   1 min read
# 14   2 min read
# 15   1 min read
# 16   5 min read
# 17   6 min read
# 18   6 min read
# 19   1 min read
# 20   3 min read
# 21   3 min read
# 22   1 min read
# 23   2 min read
# 24   2 min read
# 25   5 min read
# 26   4 min read

# %%
article = []
article_link = []

def get_full_content(second_url):
    ua = UserAgent()
    userAgent = ua.random
    headers = {'User-Agent': userAgent}
    page = requests.get(second_url, headers = headers)
    soup = BeautifulSoup(page.content, 'html.parser')
    print(second_url)
    content = soup.find('div', class_ = "crayons-article__main")

    paragraphs = content.find_all('p')
    contents = []
    for i in paragraphs:
        contents.append(i.text.replace('\n', ' '))

    string = ' '.join(contents)
    article.append(string)
    article_link.append(second_url)

for i in df.Link:
    get_full_content(i)

article_df = pd.DataFrame({
    'Article_Content': article,
    'Link': article_link
})
article_df
# Out:
# https://dev.to/pambrus/top-5-product-analytics-softwares-for-snowplow-p99
# https://dev.to/fscss/css-content-replace-and-repeat-method-fscss-4gpb
# https://dev.to/victornu/project-js-cmp-a-javascript-to-c-transpiler-feedback-welcome-23o3
# https://dev.to/zenoguy/so-i-decided-to-learn-vim-and-i-kinda-get-the-hype-now-287d
# https://dev.to/praveena_2109/benefits-of-open-source-403c
# https://dev.to/huetteldorf/introducing-gq-to-sql-convert-graph-style-url-queries-into-sql-4h5o
# https://dev.to/phanhie/markdown-for-beginners-5bbe
# https://dev.to/kashan_iqbal_ec4174ddae63/mern-vs-mevn-vs-mean-stack-what-should-you-learn-in-2025-and-why-1l40
# https://dev.to/moyantianwang/comprehensive-guide-to-arkts-component-properties-32i6
# https://dev.to/molly_scott_0605/digital-grit-why-consistency-beats-virality-in-long-term-brand-growth-1eke
# https://dev.to/jitunayak/flutter-a0m
# https://dev.to/lux_seminare/building-in-public-day-2-unpacking-the-vision-for-the-notion-developers-hub-39io
# https://dev.to/rac/algorithms-in-real-life-why-they-matter-beyond-the-classroom-1h4p
# https://dev.to/pushpitjain/hi--58g0
# https://dev.to/charlie_brinicombe/the-creator-economy-playbook-managing-125-creators-without-losing-your-mind-3i9f
# https://dev.to/ashikur_rahmannazil93/the-ai-arms-race-intensifies-altman-dismisses-metas-tactics-champions-openais-mission-in-3en2
# https://dev.to/czmilo/a2a-inspector-a-deep-dive-into-agent2agent-communication-debugging-40m9
# https://dev.to/bhuvi_d/building-something-for-digital-therapy-1adh
# https://dev.to/vivien_mahe/build-android-ios-apps-faster-with-kmpship-a-kotlin-multiplatform-boilerplate-for-indie-devs-2ogh
# https://dev.to/bhosalevijayawssa/aws-data-migration-service-dms-configurations-2cci
# https://dev.to/saber9-8/your-guide-to-basic-linux-commands-day04-564p
# https://dev.to/anil_c84dda16a00ec91d5057/how-to-format-and-validate-json-in-the-browser-3po7
# https://dev.to/seatunnel/boost-seatunnel-build-efficiency-by-60-with-maven-daemon-4ich
# https://dev.to/arnons1/how-ai-agent-companies-go-from-0-to-profitable-with-code-examples-3koc
# https://dev.to/campac/jq-the-hidden-dangers-in-your-favorite-json-tool-an-in-depth-code-analysis-301g
#                                       Article_Content  \
# 0   Snowplow is an advanced customer data platform...
# 1   Avoid syntax errors in FSCSS replacement (re()...
# 2   Hi everyone, We're working on an open-source t...
# 3   Alright, let me be honest right out the gate: ...
# 4   Hi everyone..! The Open-Source Advantage: A St...
# 5   As a developer working with Graph-like APIs an...
# 6   Markdown is a straightforward markup language ...
# 7   If you’re diving into full-stack JavaScript de...
# 8   ​Development Recommendation:​​ Prefer vp units...
# 9   In digital marketing, going viral sounds like ...
# 10
# 11  Hey Dev Community! Yesterday, the journey to b...
# 12  For many students, learning algorithms starts ...
# 13  Hi myself Pushpit jain, a software engineering...
# 14  Building a creator community that actually dri...
# 15  The escalating battle for dominance in artific...
# 16  The A2A (Agent2Agent) protocol represents a st...
# 17  You know how most of us have those incomplete ...
# 18  Over the past few years, Kotlin Multiplatform ...
# 19  A data migration to AWS involves leveraging va...
# 20  Today We are going to take a look at the cat c...
# 21  Working with JSON is part of nearly every deve...
# 22  In large-scale data integration projects, buil...
# 23  I've spoken to about 160 agent builders in the...
# 24  If you're a developer, chances are you've reac...
#
#                                                  Link
# 0   https://dev.to/pambrus/top-5-product-analytics...
# 1   https://dev.to/fscss/css-content-replace-and-r...
# 2   https://dev.to/victornu/project-js-cmp-a-javas...
# 3   https://dev.to/zenoguy/so-i-decided-to-learn-v...
# 4   https://dev.to/praveena_2109/benefits-of-open-...
# 5   https://dev.to/huetteldorf/introducing-gq-to-s...
# 6   https://dev.to/phanhie/markdown-for-beginners-...
# 7   https://dev.to/kashan_iqbal_ec4174ddae63/mern-...
# 8   https://dev.to/moyantianwang/comprehensive-gui...
# 9   https://dev.to/molly_scott_0605/digital-grit-w...
# 10               https://dev.to/jitunayak/flutter-a0m
# 11  https://dev.to/lux_seminare/building-in-public...
# 12  https://dev.to/rac/algorithms-in-real-life-why...
# 13                https://dev.to/pushpitjain/hi--58g0
# 14  https://dev.to/charlie_brinicombe/the-creator-...
# 15  https://dev.to/ashikur_rahmannazil93/the-ai-ar...
# 16  https://dev.to/czmilo/a2a-inspector-a-deep-div...
# 17  https://dev.to/bhuvi_d/building-something-for-...
# 18  https://dev.to/vivien_mahe/build-android-ios-a...
# 19  https://dev.to/bhosalevijayawssa/aws-data-migr...
# 20  https://dev.to/saber9-8/your-guide-to-basic-li...
# 21  https://dev.to/anil_c84dda16a00ec91d5057/how-t...
# 22  https://dev.to/seatunnel/boost-seatunnel-build...
# 23  https://dev.to/arnons1/how-ai-agent-companies-...
# 24  https://dev.to/campac/jq-the-hidden-dangers-in...

# %%
merged_df = pd.merge(df, article_df, on = 'Link', how='inner')

from nltk.corpus import stopwords 
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# Download the stopwords dataset
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('vader_lexicon')
nltk.download('punkt_tab')


def count_words_without_stopwords(text):
    if isinstance(text, (str, bytes)):
        words = nltk.word_tokenize(str(text))
        stop_words = set(stopwords.words('english'))
        filtered_words = [word for word in words if word.lower() not in stop_words]
        return len(filtered_words)
    else:
        0

merged_df['Word_Count'] = merged_df['Article_Content'].apply(count_words_without_stopwords)

sid = SentimentIntensityAnalyzer()

def get_sentiment(row):
    sentiment_scores = sid.polarity_scores(row)
    compound_score = sentiment_scores['compound']

    if compound_score >= 0.05:
        sentiment = 'Positive'
    elif compound_score <= -0.05:
        sentiment = 'Negative'
    else:
        sentiment = 'Neutral'

    return sentiment, compound_score

merged_df[['Sentiment', 'Compound_Score']] = merged_df['Article_Content'].astype(str).apply(lambda x: pd.Series(get_sentiment(x)))

import pandas as pd
import langid
import pycountry


def detect_language(text):
    # Convert NaN to an empty string
    text = str(text) if pd.notna(text) else ''
    
    # Use langid to detect the language
    lang, confidence = langid.classify(text)
    return lang

merged_df['Language'] = merged_df['Article_Content'].apply(detect_language)
merged_df['Language'] = merged_df['Language'].map(lambda code: pycountry.languages.get(alpha_2=code).name if pycountry.languages.get(alpha_2=code) else code)
merged_df['Reading_Time'] = merged_df['Reading_Time'].str.replace(' min read', '', regex=False).str.strip().astype(int)
merged_df
# Out:
# [nltk_data] Downloading package stopwords to /home/gitpod/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to
# 16  A2A Inspector: A Deep Dive into Agent2Agent Co...  2025-06-18T09:40:14Z
# 17             Building something for Digital Therapy  2025-06-18T09:40:01Z
# 18  Build Android & iOS Apps Faster with KMPShip: ...  2025-06-18T09:38:38Z
# 19  AWS Data migration service (DMS) configuration...  2025-06-18T09:37:48Z
# 20           Your Guide to Basic Linux Commands Day04  2025-06-18T09:34:30Z
# 21     How to Format and Validate JSON in the Browser  2025-06-18T09:33:24Z
# 22  Boost SeaTunnel Build Efficiency by 60% with M...  2025-06-18T09:32:34Z
# 23    How AI Agent Companies Go From $0 to Profitable  2025-06-18T09:30:37Z
# 24  jq: The Hidden Dangers in Your Favorite JSON T...  2025-06-18T09:28:57Z
#
#                    Authors                                               Tags  \
# 0            Ambrus Pethes  #snowplow #productanalytics #marketinganalytic...
# 1           FSCSS tutorial                                           #codepen
# 2             Victor BRAUN                      #cpp #javascript #programming
# 3            Shreyan Ghosh                  #vim #neovim #devtools #beginners
# 4           Praveena durai         #opensource #webdev #javascript #beginners
# 5                 sempre76              #webdev #microsoftgraph #sql #graphql
# 6                  Phanhie             #webdev #documentation #html #markdown
# 7             kashan iqbal
# 8                     魔眼天王                                           #harmony
# 9              Molly Scott         #brand #digitalmarketing #consistencybeats
# 10              Jitu Nayak                #flutter #dart #mobile #development
# 11            Lux Seminare           #webdev #design #waitlist #buildinpublic
# 12                Zack Rac               #webdev #programming #javascript #ai
# 13            Pushpit jain               #beginners #webdev #learning #newbie
# 14      Charlie Brinicombe                      #podcast #b2c #growth #mobile
# 15  Ashikur Rahman (NaziL)            #programming #javascript #ai #beginners
# 16                      cz                                               #a2a
# 17                 Bhuvi D                 #showdev #webdev #react #beginners
# 18             Vivien Mahé  #boilerplate #mobile #kotlin #kotlinmultiplatform
# 19     Vijay Dilip Bhosale                  #aws #awsbigdata #awsdatalake #s3
# 20               Sivakumar                                        #linux #cli
# 21                    Anil  #webdev #javascript #frontend #softwaredevelop...
# 22        Apache SeaTunnel              #seatunnel #programming #java #devops
# 23           Arnon Shimoni                                       #ai #startup
# 24                 Camillo                    #programming #cybersecurity #jq
#
#     Reading_Time                                    Article_Content  \
# 0              8  Snowplow is an advanced customer data platform...
# 1              1  Avoid syntax errors in FSCSS replacement (re()...
# 2              1  Hi everyone, We're working on an open-source t...
# 3              2  Alright, let me be honest right out the gate: ...
# 4              1  Hi everyone..! The Open-Source Advantage: A St...
# 5              1  As a developer working with Graph-like APIs an...
# 6              4  Markdown is a straightforward markup language ...
# 7              3  If you’re diving into full-stack JavaScript de...
# 8              2  ​Development Recommendation:​​ Prefer vp units...
# 9              5  In digital marketing, going viral sounds like ...
# 10             1
# 11             1  Hey Dev Community! Yesterday, the journey to b...
# 12             2  For many students, learning algorithms starts ...
# 13             1  Hi myself Pushpit jain, a software engineering...
# 14             5  Building a creator community that actually dri...
# 15             6  The escalating battle for dominance in artific...
# 16             6  The A2A (Agent2Agent) protocol represents a st...
# 17             1  You know how most of us have those incomplete ...
# 18             3  Over the past few years, Kotlin Multiplatform ...
# 19             3  A data migration to AWS involves leveraging va...
# 20             1  Today We are going to take a look at the cat c...
# 21             2  Working with JSON is part of nearly every deve...
# 22             2  In large-scale data integration projects, buil...
# 23             5  I've spoken to about 160 agent builders in the...
# 24             4  If you're a developer, chances are you've reac...
#
#     Word_Count Sentiment  Compound_Score Language
# 0          688  Positive          0.9981  English
# 1           23  Negative         -0.5574  English
# 2          117  Positive          0.9191  English
# 3          231  Positive          0.6704  English
# 4          129  Positive          0.9872  English
# 5          134  Positive          0.9388  English
# 6          396  Positive          0.9974  English
# 7          237  Positive          0.9850  English
# 8           41  Positive          0.5574  English
# 9          897  Positive          0.9997  English
# 10           0   Neutral          0.0000  English
# 11         126  Positive          0.9395  English
# 12         389  Positive          0.9960  English
# 13         146  Positive          0.2846  English
# 14         759  Positive          0.9995  English
# 15         991  Positive          0.9996  English
# 16         434  Positive          0.9788  English
# 17         137  Positive          0.9926  English
# 18         284  Positive          0.9925  English
# 19         537  Positive          0.9933  English
# 20          86  Positive          0.4215  English
# 21         159  Positive          0.9590  English
# 22         162  Positive          0.8832  English
# 23         706  Positive          0.9938  English
# 24         561  Positive          0.9973  English

# %%
merged_df.dtypes
# Out:
# Link                object
# Title               object
# Time_Uploaded       object
# Authors             object
# Tags                object
# Reading_Time         int64
# Article_Content     object
# Word_Count           int64
# Sentiment           object
# Compound_Score     float64
# Language            object
# dtype: object

# %%
# CREATE TABLE IF NOT EXISTS articles (
# Link TEXT PRIMARY KEY,
# Title TEXT, 
# Time_Uploaded TIMESTAMP,
# Authors TEXT,
# Tags TEXT,
# Reading_Time INTEGER,
# Article_Content TEXT,
# Word_Count INTEGER,
# Sentiment TEXT,
# Compound_Score NUMERIC,
# Language TEXT
# );

# %%
import psycopg2
db_params = {
    "dbname": "postgres",
    "user": "",
    "password": '',
    "host": "",
    "port": "5432"
}
try:
    # Connect to PostgreSQL
    conn = psycopg2.connect(**db_params)
    cursor = conn.cursor()
    
    # SQL Insert Query
    insert_query = """
    INSERT INTO articles (Link, Title, Time_Uploaded, Authors, Tags, Reading_Time, Article_Content, Word_Count, Sentiment, Compound_Score, Language)
    VALUES (%s, %s, %s, %s, %s, %s, %s,%s, %s, %s, %s)
    ON CONFLICT (Link) DO NOTHING;  -- Avoids duplicate primary key errors
    """
    
    # Insert DataFrame records one by one
    for _, row in merged_df.iterrows():
        cursor.execute(insert_query, (
            row['Link'], row['Title'], row['Time_Uploaded'],  row['Authors'], row['Tags'], row['Reading_Time'],
            row['Article_Content'],row['Word_Count'],row['Sentiment'],row['Compound_Score'],row['Language']
        ))

    # Commit and close
    conn.commit()
    print("Data inserted successfully!")

except Exception as e:
    print(e)

finally:
    if conn:
        cursor.close()
        conn.close
# Out:
# Data inserted successfully!

# %%
df.to_sql
