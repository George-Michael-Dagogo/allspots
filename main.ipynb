# %%
pip install requests pandas fake_useragent bs4 langid pycountry nltk

# %%
import requests
from bs4 import BeautifulSoup
from fake_useragent import UserAgent
import pandas as pd
import os

url = 'https://dev.to/latest'

ua = UserAgent()
userAgent = ua.random
headers = {'User-Agent': userAgent}
page = requests.get(url, headers = headers)
soup = BeautifulSoup(page.content, 'html.parser')

# %%
blog_box = soup.find_all('div', class_='crayons-story')

links = []
titles = []
time_uploaded = []
authors = []
tags = []
reading_times = []

for box in blog_box:
    #links
    if box.find('h2', class_ = 'crayons-story__title') is not None:
        link = box.find('h2', class_ = 'crayons-story__title').a
        link = link['href']
        links.append(link)
    else:
        links.append('None')

    #titles
    if box.find('h2', class_ = 'crayons-story__title') is not None:
        title = box.find('h2', class_ = 'crayons-story__title')
        titles.append(title.text.replace('\n','').strip())
    else:
        titles.append('None')

    #time_uploaded
    if box.find('time', attrs={'datetime': True}) is not None:
        time_upload = box.find('time', attrs={'datetime': True})
        time_upload = time_upload['datetime']
        time_uploaded.append(time_upload)
    else:
        time_uploaded.append('None')

    #authors
    if box.find('a', class_ = 'crayons-story__secondary fw-medium m:hidden') is not None:
        author = box.find('a', class_ = 'crayons-story__secondary fw-medium m:hidden')
        authors.append(author.text.replace('\n','').strip())
    else:
        authors.append('None')

    #tags
    if box.find('div', class_ = "crayons-story__tags") is not None:
        tag = box.find('div', class_ = "crayons-story__tags")
        tags.append(tag.text.replace('\n',' ').strip())
    else:
        tags.append('None')

    #reading_times
    if box.find('div', class_ = "crayons-story__save") is not None:
        reading_time = box.find('div', class_ = "crayons-story__save")
        reading_times.append(reading_time.text.replace('\n',' ').strip())
    else:
        reading_times.append('None')


df = pd.DataFrame({
    'Link': links,
    'Title': titles,
    'Time_Uploaded': time_uploaded,
    'Authors': authors,
    'Tags': tags,
    'Reading_Time': reading_times
})

df = df[df['Link'] != 'None']

df
# Out:
#                                                  Link  \
# 2   https://dev.to/empiree/the-story-behind-multid...
# 3   https://dev.to/thejuanchua/this-article-helped...
# 4   https://dev.to/thejuanchua/i-sent-this-to-our-...
# 5   https://dev.to/thejuanchua/what-stands-out-her...
# 6   https://dev.to/vaib/the-ai-revolution-in-ethic...
# 7     https://dev.to/mahir_dasare_333/hard-links-3aep
# 8   https://dev.to/__432d93ec/fancy-fading-footer-...
# 9   https://dev.to/vaib/the-internet-of-behaviors-...
# 10   https://dev.to/amzyei/pck3r-package-manager-2pib
# 11  https://dev.to/vaib/the-prompt-engineers-evolu...
# 12  https://dev.to/mohitscodiclab/ultimate-full-st...
# 13  https://dev.to/vaib/bridging-the-quantum-gap-a...
# 14  https://dev.to/kevinccbsg/react-router-data-mo...
# 15  https://dev.to/goldennoodles/so-you-want-to-be...
# 16  https://dev.to/nanditha_vuppunuthula_d09/kafka...
# 17  https://dev.to/gagan_nadiger_3cf2b4d9615/ai-po...
# 18  https://dev.to/gamecoder/deadlock-deadlock-fil...
# 19  https://dev.to/jetthoughts/the-simplicity-para...
# 20  https://dev.to/hemant_007/germanys-ai-autobahn...
# 21  https://dev.to/railsdesigner/introducing-turbo...
# 22  https://dev.to/techsolver94/master-javascript-...
# 23  https://dev.to/exavier_jaguileradev/blazor-y-n...
# 24  https://dev.to/aimee1980/hello-dev-community-2bc3
# 25  https://dev.to/michael_watson_8780e10ad7/model...
# 26  https://dev.to/ericluckson1999/pidm-python-int...
#
#                                                 Title         Time_Uploaded  \
# 2                         The Story Behind MultiDrive  2025-06-12T18:56:38Z
# 3   This article helped me understand that remote ...  2025-06-12T19:10:33Z
# 4   I sent this to our HR and security teams right...  2025-06-12T19:09:07Z
# 5   What stands out here is the way emotion and st...  2025-06-12T19:07:49Z
# 6   The AI Revolution in Ethical Hacking: Empoweri...  2025-06-12T19:07:19Z
# 7                                          Hard Links  2025-06-12T19:06:32Z
# 8                                 Fancy Fading Footer  2025-06-12T19:04:02Z
# 9   The Internet of Behaviors: Navigating the Ethi...  2025-06-12T19:02:57Z
# 10      PCK3R : Package manager [V1.0] Windows 10 X64  2025-06-12T19:00:37Z
# 11  The Prompt Engineer's Evolution: Mastering Aut...  2025-06-12T19:00:07Z
# 12  Ultimate Full Stack Web Development Roadmap - ...  2025-06-12T18:58:07Z
# 13  Bridging the Quantum Gap: A Guide to Hybrid Qu...  2025-06-12T18:49:43Z
# 14  React Router Data Mode: Parte 6 – Actions, for...  2025-06-12T18:48:58Z
# 15             So You Want to Be a Senior Engineer...  2025-06-12T18:33:21Z
# 16                                           Kafka MQ  2025-06-12T18:28:31Z
# 17  AI-Powered Rock Paper Scissors Game with Amazo...  2025-06-12T18:24:57Z
# 18                          DeadLock - dead.lock file  2025-06-12T18:24:28Z
# 19  The Simplicity Paradox: Why Your Startup's Tec...  2025-06-12T18:23:46Z
# 20  🚀 Germany’s AI Autobahn: Accelerating a Nation...  2025-06-12T18:23:38Z
# 21  Introducing Turbo Transition: create smoother ...  2025-06-12T18:15:00Z
# 22  🔥 Master JavaScript Objects: The Ultimate Guid...  2025-06-12T18:07:52Z
# 23  ¡Blazor y .NET 9: Desbloqueando la Velocidad E...  2025-06-12T18:07:24Z
# 24                                Hello DEV community  2025-06-12T18:03:50Z
# 25  Model Context Protocol (MCP) is the React Mome...  2025-06-12T18:03:44Z
# 26            PIDM - python internet download manager  2025-06-12T18:01:25Z
#
#                           Authors  \
# 2                    Oleg Dubovoi
# 3                       Juan Chua
# 4                       Juan Chua
# 5                       Juan Chua
# 6                           Coder
# 7                    mahir dasare
# 8                پیمان مجیدی معین
# 9                           Coder
# 10                         AMZYEI
# 11                          Coder
# 12                    Mohit Kumar
# 13                          Coder
# 14  Kevin Julián Martínez Escobar
# 15                     Rus Kuzmin
# 16          Nanditha Vuppunuthula
# 17                  Gagan Nadiger
# 18                Chitransh Soral
# 19                      Paul Keen
# 20                         Hemant
# 21                 Rails Designer
# 22              TechSolve Central
# 23           Exavier J Aguilera V
# 24                      aimee1980
# 25                 Michael Watson
# 26                           Eric
#
#                                                  Tags Reading_Time
# 2         #programming #csharp #dotnet #cybersecurity  10 min read
# 3   #remotework #productivity #ashkanrajaee #techi...   1 min read
# 4   #remotehiring #cybersecurity #developerjobs #a...   1 min read
# 5   #ashkanrajaee #mindset #careerchange #personal...   1 min read
# 6        #ai #cybersecurity #ethicalhacking #security   4 min read
# 7                                                       2 min read
# 8                                            #codepen   1 min read
# 9                                                       5 min read
# 10                        #microsoft #xamarin #cpp #c   1 min read
# 11                                                      6 min read
# 12                                                      2 min read
# 13                                                      2 min read
# 14            #webdev #javascript #react #reactrouter   5 min read
# 15     #discuss #programming #beginners #productivity   3 min read
# 16                                                      5 min read
# 17               #webdev #amazonqcli #programming #ai   2 min read
# 18  #python #opensource #datascience #machinelearning   1 min read
# 19               #webdev #startup #agile #programming   6 min read
# 20        #ai #nvidiachallenge #deeplearning #germany   3 min read
# 21                  #rails #ruby #hotwire #javascript   3 min read
# 22  #javascript #programming #coding #softwaredeve...   1 min read
# 23                    #csharp #webdev #blazor #dotnet   5 min read
# 24    #github #sideprojects #gamechallenge #portfolio   1 min read
# 25                           #mcp #ai #react #graphql   6 min read
# 26             #programming #python #pidm #opensource   2 min read

# %%
article = []
article_link = []

def get_full_content(second_url):
    ua = UserAgent()
    userAgent = ua.random
    headers = {'User-Agent': userAgent}
    page = requests.get(second_url, headers = headers)
    soup = BeautifulSoup(page.content, 'html.parser')
    print(second_url)
    content = soup.find('div', class_ = "crayons-article__main")

    paragraphs = content.find_all('p')
    contents = []
    for i in paragraphs:
        contents.append(i.text.replace('\n', ' '))

    string = ' '.join(contents)
    article.append(string)
    article_link.append(second_url)

for i in df.Link:
    get_full_content(i)

article_df = pd.DataFrame({
    'Article_Content': article,
    'Link': article_link
})
article_df
# Out:
# https://dev.to/empiree/the-story-behind-multidrive-eo8
# https://dev.to/thejuanchua/this-article-helped-me-understand-that-remote-work-is-not-just-about-flexibility-but-also-about-4p0f
# https://dev.to/thejuanchua/i-sent-this-to-our-hr-and-security-teams-right-after-reading-it-better-safe-than-sorry-4io
# https://dev.to/thejuanchua/what-stands-out-here-is-the-way-emotion-and-strategy-are-blended-very-few-posts-do-that-well-2bgk
# https://dev.to/vaib/the-ai-revolution-in-ethical-hacking-empowering-defenders-in-the-digital-age-52ag
# https://dev.to/mahir_dasare_333/hard-links-3aep
# https://dev.to/__432d93ec/fancy-fading-footer-3i71
# https://dev.to/vaib/the-internet-of-behaviors-navigating-the-ethical-tightrope-1en5
# https://dev.to/amzyei/pck3r-package-manager-2pib
# https://dev.to/vaib/the-prompt-engineers-evolution-mastering-automated-optimization-and-human-centric-ai-4jj
# https://dev.to/mohitscodiclab/ultimate-full-stack-web-development-roadmap-2025-5fk3
# https://dev.to/vaib/bridging-the-quantum-gap-a-guide-to-hybrid-quantum-classical-algorithms-343g
# https://dev.to/kevinccbsg/react-router-data-mode-parte-6-actions-formularios-y-mutaciones-5354
# https://dev.to/goldennoodles/so-you-want-to-be-a-senior-engineer-2jl3
# https://dev.to/nanditha_vuppunuthula_d09/kafka-mq-304d
# https://dev.to/gagan_nadiger_3cf2b4d9615/ai-powered-rock-paper-scissors-game-with-amazon-q-cli-a-journey-in-ai-assisted-game-development-3p84
# https://dev.to/gamecoder/deadlock-deadlock-file-5cam
# https://dev.to/jetthoughts/the-simplicity-paradox-why-your-startups-technical-strategy-should-be-boring-1ie8
# https://dev.to/hemant_007/germanys-ai-autobahn-accelerating-a-nations-digital-future-with-nvidia-3oii
# https://dev.to/railsdesigner/introducing-turbo-transition-create-smoother-turbo-streams-3i4n
# https://dev.to/techsolver94/master-javascript-objects-the-ultimate-guide-with-real-world-examples-25c4
# https://dev.to/exavier_jaguileradev/blazor-y-net-9-desbloqueando-la-velocidad-extrema-con-server-side-rendering-ssr-estatico-para-5d4b
# https://dev.to/aimee1980/hello-dev-community-2bc3
# https://dev.to/michael_watson_8780e10ad7/model-context-protocol-mcp-is-the-react-moment-for-ai-3nhg
# https://dev.to/ericluckson1999/pidm-python-internet-download-manager-2hde
#                                       Article_Content  \
# 0   Hello, Dev.to community! This is the story of ...
# 1
# 2
# 3
# 4   The AI Revolution in Ethical Hacking: Empoweri...
# 5   The ln utility is used to create hard links an...
# 6   Made for this video: https://www.youtube.com/w...
# 7   The Internet of Behaviors (IoB) represents a r...
# 8   Pck3r is a modern package manager for Windows ...
# 9   The Prompt Engineer's Evolution: Mastering Aut...
# 10  Are you dreaming of becoming a full stack web ...
# 11  The promise of quantum computing to revolution...
# 12  Continuamos con la sexta entrega de esta serie...
# 13  Ah yes, the elusive title: Senior Software Eng...
# 14  Kafka is a publish/subscribe (pub/sub) messagi...
# 15  Introduction I'm excited to share my journey o...
# 16  Hello guys, I am excited to share that today I...
# 17  Navigating the counterintuitive relationship b...
# 18  Hello Dev Community! 👋 This is ❤️‍🔥 Hemant Kat...
# 19  This article was originally published on Rails...
# 20  JavaScript objects are the backbone of the lan...
# 21  : ¿Por qué la Velocidad y el SEO son Clave en ...
# 22  My Current Projects 🧾 QuickBooks Clone A full-...
# 23  The Model Context Protocol (MCP) is AI's React...
# 24  Smart, Open, and Built for Power Users PIDM is...
#
#                                                  Link
# 0   https://dev.to/empiree/the-story-behind-multid...
# 1   https://dev.to/thejuanchua/this-article-helped...
# 2   https://dev.to/thejuanchua/i-sent-this-to-our-...
# 3   https://dev.to/thejuanchua/what-stands-out-her...
# 4   https://dev.to/vaib/the-ai-revolution-in-ethic...
# 5     https://dev.to/mahir_dasare_333/hard-links-3aep
# 6   https://dev.to/__432d93ec/fancy-fading-footer-...
# 7   https://dev.to/vaib/the-internet-of-behaviors-...
# 8    https://dev.to/amzyei/pck3r-package-manager-2pib
# 9   https://dev.to/vaib/the-prompt-engineers-evolu...
# 10  https://dev.to/mohitscodiclab/ultimate-full-st...
# 11  https://dev.to/vaib/bridging-the-quantum-gap-a...
# 12  https://dev.to/kevinccbsg/react-router-data-mo...
# 13  https://dev.to/goldennoodles/so-you-want-to-be...
# 14  https://dev.to/nanditha_vuppunuthula_d09/kafka...
# 15  https://dev.to/gagan_nadiger_3cf2b4d9615/ai-po...
# 16  https://dev.to/gamecoder/deadlock-deadlock-fil...
# 17  https://dev.to/jetthoughts/the-simplicity-para...
# 18  https://dev.to/hemant_007/germanys-ai-autobahn...
# 19  https://dev.to/railsdesigner/introducing-turbo...
# 20  https://dev.to/techsolver94/master-javascript-...
# 21  https://dev.to/exavier_jaguileradev/blazor-y-n...
# 22  https://dev.to/aimee1980/hello-dev-community-2bc3
# 23  https://dev.to/michael_watson_8780e10ad7/model...
# 24  https://dev.to/ericluckson1999/pidm-python-int...

# %%
merged_df = pd.merge(df, article_df, on = 'Link', how='inner')

from nltk.corpus import stopwords 
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# Download the stopwords dataset
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('vader_lexicon')
nltk.download('punkt_tab')


def count_words_without_stopwords(text):
    if isinstance(text, (str, bytes)):
        words = nltk.word_tokenize(str(text))
        stop_words = set(stopwords.words('english'))
        filtered_words = [word for word in words if word.lower() not in stop_words]
        return len(filtered_words)
    else:
        0

merged_df['Word_Count'] = merged_df['Article_Content'].apply(count_words_without_stopwords)

sid = SentimentIntensityAnalyzer()

def get_sentiment(row):
    sentiment_scores = sid.polarity_scores(row)
    compound_score = sentiment_scores['compound']

    if compound_score >= 0.05:
        sentiment = 'Positive'
    elif compound_score <= -0.05:
        sentiment = 'Negative'
    else:
        sentiment = 'Neutral'

    return sentiment, compound_score

merged_df[['Sentiment', 'Compound_Score']] = merged_df['Article_Content'].astype(str).apply(lambda x: pd.Series(get_sentiment(x)))

import pandas as pd
import langid
import pycountry


def detect_language(text):
    # Convert NaN to an empty string
    text = str(text) if pd.notna(text) else ''
    
    # Use langid to detect the language
    lang, confidence = langid.classify(text)
    return lang

merged_df['Language'] = merged_df['Article_Content'].apply(detect_language)
merged_df['Language'] = merged_df['Language'].map(lambda code: pycountry.languages.get(alpha_2=code).name if pycountry.languages.get(alpha_2=code) else code)
merged_df
# Out:
#                                                  Link  \
# 0   https://dev.to/empiree/the-story-behind-multid...
# 1   https://dev.to/thejuanchua/this-article-helped...
# 2   https://dev.to/thejuanchua/i-sent-this-to-our-...
# 3   https://dev.to/thejuanchua/what-stands-out-her...
# 4   https://dev.to/vaib/the-ai-revolution-in-ethic...
# 5     https://dev.to/mahir_dasare_333/hard-links-3aep
# 6   https://dev.to/__432d93ec/fancy-fading-footer-...
# 7   https://dev.to/vaib/the-internet-of-behaviors-...
# 8    https://dev.to/amzyei/pck3r-package-manager-2pib
# 9   https://dev.to/vaib/the-prompt-engineers-evolu...
# 10  https://dev.to/mohitscodiclab/ultimate-full-st...
# 11  https://dev.to/vaib/bridging-the-quantum-gap-a...
# 12  https://dev.to/kevinccbsg/react-router-data-mo...
# 13  https://dev.to/goldennoodles/so-you-want-to-be...
# 14  https://dev.to/nanditha_vuppunuthula_d09/kafka...
# 15  https://dev.to/gagan_nadiger_3cf2b4d9615/ai-po...
# 16  https://dev.to/gamecoder/deadlock-deadlock-fil...
# 17  https://dev.to/jetthoughts/the-simplicity-para...
# 18  https://dev.to/hemant_007/germanys-ai-autobahn...
# 19  https://dev.to/railsdesigner/introducing-turbo...
# 20  https://dev.to/techsolver94/master-javascript-...
# 21  https://dev.to/exavier_jaguileradev/blazor-y-n...
# 22  https://dev.to/aimee1980/hello-dev-community-2bc3
# 23  https://dev.to/michael_watson_8780e10ad7/model...
# 24  https://dev.to/ericluckson1999/pidm-python-int...
#
#                                                 Title         Time_Uploaded  \
# 0                         The Story Behind MultiDrive  2025-06-12T18:56:38Z
# 1   This article helped me understand that remote ...  2025-06-12T19:10:33Z
# 2   I sent this to our HR and security teams right...  2025-06-12T19:09:07Z
# 3   What stands out here is the way emotion and st...  2025-06-12T19:07:49Z
# 4   The AI Revolution in Ethical Hacking: Empoweri...  2025-06-12T19:07:19Z
# 5                                          Hard Links  2025-06-12T19:06:32Z
# 6                                 Fancy Fading Footer  2025-06-12T19:04:02Z
# 7   The Internet of Behaviors: Navigating the Ethi...  2025-06-12T19:02:57Z
# 8       PCK3R : Package manager [V1.0] Windows 10 X64  2025-06-12T19:00:37Z
# 9   The Prompt Engineer's Evolution: Mastering Aut...  2025-06-12T19:00:07Z
# 10  Ultimate Full Stack Web Development Roadmap - ...  2025-06-12T18:58:07Z
# 11  Bridging the Quantum Gap: A Guide to Hybrid Qu...  2025-06-12T18:49:43Z
# 12  React Router Data Mode: Parte 6 – Actions, for...  2025-06-12T18:48:58Z
# 13             So You Want to Be a Senior Engineer...  2025-06-12T18:33:21Z
# 14                                           Kafka MQ  2025-06-12T18:28:31Z
# 15  AI-Powered Rock Paper Scissors Game with Amazo...  2025-06-12T18:24:57Z
# 16                          DeadLock - dead.lock file  2025-06-12T18:24:28Z
# 17  The Simplicity Paradox: Why Your Startup's Tec...  2025-06-12T18:23:46Z
# 18  🚀 Germany’s AI Autobahn: Accelerating a Nation...  2025-06-12T18:23:38Z
# 19  Introducing Turbo Transition: create smoother ...  2025-06-12T18:15:00Z
# 20  🔥 Master JavaScript Objects: The Ultimate Guid...  2025-06-12T18:07:52Z
# 21  ¡Blazor y .NET 9: Desbloqueando la Velocidad E...  2025-06-12T18:07:24Z
# 22                                Hello DEV community  2025-06-12T18:03:50Z
# 23  Model Context Protocol (MCP) is the React Mome...  2025-06-12T18:03:44Z
# 24            PIDM - python internet download manager  2025-06-12T18:01:25Z
#
#                           Authors  \
# 0                    Oleg Dubovoi
# 1                       Juan Chua
# 2                       Juan Chua
# 3                       Juan Chua
# 4                           Coder
# 5                    mahir dasare
# 6                پیمان مجیدی معین
# 7                           Coder
# 8                          AMZYEI
# 9                           Coder
# 10                    Mohit Kumar
# 11                          Coder
# 12  Kevin Julián Martínez Escobar
# 13                     Rus Kuzmin
# 14          Nanditha Vuppunuthula
# 15                  Gagan Nadiger
# 16                Chitransh Soral
# 17                      Paul Keen
# 18                         Hemant
# 19                 Rails Designer
# 20              TechSolve Central
# 21           Exavier J Aguilera V
# 22                      aimee1980
# 23                 Michael Watson
# 24                           Eric
#
#                                                  Tags Reading_Time  \
# 0         #programming #csharp #dotnet #cybersecurity  10 min read
# 1   #remotework #productivity #ashkanrajaee #techi...   1 min read
# 2   #remotehiring #cybersecurity #developerjobs #a...   1 min read
# 3   #ashkanrajaee #mindset #careerchange #personal...   1 min read
# 4        #ai #cybersecurity #ethicalhacking #security   4 min read
# 5                                                       2 min read
# 6                                            #codepen   1 min read
# 7                                                       5 min read
# 8                         #microsoft #xamarin #cpp #c   1 min read
# 9                                                       6 min read
# 10                                                      2 min read
# 11                                                      2 min read
# 12            #webdev #javascript #react #reactrouter   5 min read
# 13     #discuss #programming #beginners #productivity   3 min read
# 14                                                      5 min read
# 15               #webdev #amazonqcli #programming #ai   2 min read
# 16  #python #opensource #datascience #machinelearning   1 min read
# 17               #webdev #startup #agile #programming   6 min read
# 18        #ai #nvidiachallenge #deeplearning #germany   3 min read
# 19                  #rails #ruby #hotwire #javascript   3 min read
# 20  #javascript #programming #coding #softwaredeve...   1 min read
# 21                    #csharp #webdev #blazor #dotnet   5 min read
# 22    #github #sideprojects #gamechallenge #portfolio   1 min read
# 23                           #mcp #ai #react #graphql   6 min read
# 24             #programming #python #pidm #opensource   2 min read
#
#                                       Article_Content
# 0   Hello, Dev.to community! This is the story of ...
# 1
# 2
# 3
# 4   The AI Revolution in Ethical Hacking: Empoweri...
# 5   The ln utility is used to create hard links an...
# 6   Made for this video: https://www.youtube.com/w...
# 7   The Internet of Behaviors (IoB) represents a r...
# 8   Pck3r is a modern package manager for Windows ...
# 9   The Prompt Engineer's Evolution: Mastering Aut...
# 10  Are you dreaming of becoming a full stack web ...
# 11  The promise of quantum computing to revolution...
# 12  Continuamos con la sexta entrega de esta serie...
# 13  Ah yes, the elusive title: Senior Software Eng...
# 14  Kafka is a publish/subscribe (pub/sub) messagi...
# 15  Introduction I'm excited to share my journey o...
# 16  Hello guys, I am excited to share that today I...
# 17  Navigating the counterintuitive relationship b...
# 18  Hello Dev Community! 👋 This is ❤️‍🔥 Hemant Kat...
# 19  This article was originally published on Rails...
# 20  JavaScript objects are the backbone of the lan...
# 21  : ¿Por qué la Velocidad y el SEO son Clave en ...
# 22  My Current Projects 🧾 QuickBooks Clone A full-...
# 23  The Model Context Protocol (MCP) is AI's React...
# 24  Smart, Open, and Built for Power Users PIDM is...
